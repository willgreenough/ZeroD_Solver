# %%
import numpy as np
import pandas as pd
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def model(POut,t):
    R = 1
    C = 1
    L = 1
    QOut_t = np.sin(t) + 1 #Qout(t) outflow as a fucntion of time
    PIn_t = np.cos(t) + 2 #Pin(t) Pressure in as a fucntion of time
    # dQoutdt = np.gradient() need to include the gradient term here (in f_t)
    f_t = - QOut_t*R/(C*L) + PIn_t/(L*C)
    return (POut[1],-POut[1]*R/L - POut[0]/(L*C) + f_t)

# %%
POut0 = [1,-1] #Initial conditions for flow Out velocity and it's derivative

t = np.linspace(0,100,1000)
print(type(t))
POut_t = odeint(model,POut0,t)
POut_t = POut_t[:,0]
plt.plot(t,POut_t)
# Out:
# <class 'numpy.ndarray'>

# %%
# N_Nodes = np.array([0,0,0],[1,0,0])
# connectivity = np.array([[1,0],[0,1]])

# %%
# class Network:
#     def init(self, N_Nodes, Connectivity, Boundaries, BCs):
#         '''N_Nodes is an mx3 Matrix where m is the number of network nodes
#         (corresponding to vessel inititaiton, termination and bifurcationpoints) 
#         nodes and 4 represents the (x,y,z),
#         Connectivity is an mxm matrix that defines which nodes are connected together
#         '''
#     def compute_params():
#         return
